# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
df = pd.read_csv('./housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
x = df.drop('ocean_proximity', axis=1)
x = x.drop('total_bedrooms', axis=1)
x = x.drop('median_house_value', axis=1)
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                  41          880         322
# 1        -122.22     37.86                  21         7099        2401
# 2        -122.24     37.85                  52         1467         496
# 3        -122.25     37.85                  52         1274         558
# 4        -122.25     37.85                  52         1627         565
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                  25         1665         845
# 20636    -121.21     39.49                  18          697         356
# 20637    -121.22     39.43                  17         2254        1007
# 20638    -121.32     39.43                  18         1860         741
# 20639    -121.24     39.37                  16         2785        1387
#
#        households  median_income
# 0             126         8.3252
# 1            1138         8.3014
# ...

# %%
y = df['median_house_value']
y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20640, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=10)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 7151     -118.15     34.03                  43         2006        1687
# 10511    -117.69     33.53                  17         5041        2396
# 17312    -119.72     34.77                  35         2469        1168
# 15301    -117.36     33.18                  39         1546         833
# 6296     -117.91     34.02                  17         5973        4349
# ...          ...       ...                 ...          ...         ...
# 9372     -122.53     37.93                  37         1722         648
# 7291     -118.22     33.98                  18         1781        1913
# 17728    -121.79     37.32                   6         2850        2160
# 7293     -118.23     33.98                  35         1366        2160
# 17673    -121.88     37.30                  16         2692        1674
#
#        households  median_income
# 7151          463         1.7991
# 10511         801         6.0868
# ...

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 20303    -119.18     34.16                  12          460         405
# 16966    -122.31     37.55                  27         3931        1877
# 10623    -117.77     33.67                  12         4329        1913
# 6146     -117.95     34.11                  29         1986        2013
# 2208     -119.87     36.81                   6         1891         969
# ...          ...       ...                 ...          ...         ...
# 9007     -118.60     34.09                  43         2228         960
# 2467     -119.83     36.54                  31         1732         979
# 15480    -117.13     33.15                  15         2241         997
# 19597    -120.92     37.59                  26         1705         642
# 8300     -118.14     33.76                  50          914         322
#
#        households  median_income
# 20303         103         5.2783
# 16966         851         3.9722
# ...

# %%
y_train
# Out:
# 7151     158800
# 10511    282900
# 17312     62100
# 15301    185400
# 6296     199300
#           ...
# 9372     310300
# 7291     255000
# 17728    241900
# 7293     150000
# 17673    191100
# Name: median_house_value, Length: 15480, dtype: int64

# %%
y_test
# Out:
# 20303    167400
# 16966    354100
# 10623    160200
# 6146     140800
# 2208     107800
#           ...
# 9007     438500
# 2467      60000
# 15480    193200
# 19597    180500
# 8300     418800
# Name: median_house_value, Length: 5160, dtype: int64

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([276507.84508079, 273371.40767317, 265166.45445529, ...,
#        181091.92883592, 126883.07883282, 283495.28935777])

# %%
import matplotlib.pyplot as plt

# %%
y_changed = pd.DataFrame({'Actual': y_test, 'Predicted': y_predict, 'Difference': y_test-y_predict})
y_changed
# Out:
#        Actual      Predicted     Difference
# 20303  167400  276507.845081 -109107.845081
# 16966  354100  273371.407673   80728.592327
# 10623  160200  265166.454455 -104966.454455
# 6146   140800  142171.775123   -1371.775123
# 2208   107800  169581.197790  -61781.197790
# ...       ...            ...            ...
# 9007   438500  395891.736518   42608.263482
# 2467    60000  120491.857880  -60491.857880
# 15480  193200  181091.928836   12108.071164
# 19597  180500  126883.078833   53616.921167
# 8300   418800  283495.289358  135304.710642
#
# [5160 rows x 3 columns]

# %%
plt.scatter(x=y_test, y=y_predict)
plt.xlabel("Original Values")
plt.ylabel("Predicted Values")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Using normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
x_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.fit_transform(x_test)

# %%
model.fit(x_norm, y_train)
y_pred_norm = model.predict(x_test_norm)

# %%
y_changed_norm = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_norm, 'Difference': y_test-y_pred_norm})
y_changed_norm
# Out:
#        Actual      Predicted     Difference
# 20303  167400  256363.995820  -88963.995820
# 16966  354100  200891.475343  153208.524657
# 10623  160200  191799.283696  -31599.283696
# 6146   140800   50691.009725   90108.990275
# 2208   107800  126605.541370  -18805.541370
# ...       ...            ...            ...
# 9007   438500  355280.318990   83219.681010
# 2467    60000   76284.361177  -16284.361177
# 15480  193200  137655.323800   55544.676200
# 19597  180500   98084.643975   82415.356025
# 8300   418800  268066.006299  150733.993701
#
# [5160 rows x 3 columns]

# %%
plt.scatter(x=y_test, y=y_pred_norm)
plt.xlabel("Original Values")
plt.ylabel("Predicted Values")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
